# %%
import pandas as ps

# %%
employee = ps.read_table("C:/MyDocuments/ProfessionalDevelopment/TechnicalSkillDevelopment/DataScience/UdemyCourses/LearnDataAnalysisWithPandas/Resources/Tab_separated_values.tsv")
employee.head()

cols = ["Name", "Position"]
employee[cols]
# Out:
#                    Name                       Position
# 0            Airi Satou                     Accountant
# 1        Angelica Ramos  Chief Executive Officer (CEO)
# 2            Ashton Cox        Junior Technical Author
# 3         Bradley Greer              Software Engineer
# 4        Brenden Wagner              Software Engineer
# 5    Brielle Williamson         Integration Specialist
# 6            Bruno Nash              Software Engineer
# 7          Caesar Vance              Pre-Sales Support
# 8          Cara Stevens                Sales Assistant
# 9          Cedric Kelly    Senior Javascript Developer
# 10      Charde Marshall              Regional Director
# 11        Colleen Hurst           Javascript Developer
# 12             Dai Rios                 Personnel Lead
# 13         Donna Snider               Customer Support
# 14         Doris Wilder                Sales Assistant
# 15         Finn Camacho               Support Engineer
# 16          Fiona Green  Chief Operating Officer (COO)
# 17      Garrett Winters                     Accountant
# 18         Gavin Cortez                    Team Leader
# 19          Gavin Joyce                      Developer
# 20        Gloria Little          Systems Administrator
# 21        Haley Kennedy      Senior Marketing Designer
# 22      Hermione Butler              Regional Director
# 23      Herrod Chandler                Sales Assistant
# 24         Hope Fuentes                      Secretary
# 25      Howard Hatfield                 Office Manager
# 26     Jackson Bradshaw                       Director
# 27          Jena Gaines                 Office Manager
# 28     Jenette Caldwell               Development Lead
# 29      Jennifer Acosta    Junior Javascript Developer
# 30       Jennifer Chang              Regional Director
# 31      Jonas Alexander                      Developer
# 32           Lael Greer          Systems Administrator
# 33       Martena Mccray             Post-Sales support
# 34        Michael Bruce           Javascript Developer
# 35        Michael Silva             Marketing Designer
# 36       Michelle House         Integration Specialist
# 37         Olivia Liang               Support Engineer
# 38            Paul Byrd  Chief Financial Officer (CFO)
# 39    Prescott Bartlett               Technical Author
# 40          Quinn Flynn                   Support Lead
# 41       Rhona Davidson         Integration Specialist
# 42      Sakura Yamamoto               Support Engineer
# 43        Serge Baldwin               Data Coordinator
# 44          Shad Decker              Regional Director
# 45            Shou Itou             Regional Marketing
# 46          Sonya Frost              Software Engineer
# 47           Suki Burks                      Developer
# 48  Tatyana Fitzpatrick              Regional Director
# 49          Thor Walton                      Developer
# 50          Tiger Nixon               System Architect
# 51       Timothy Mooney                 Office Manager
# 52         Unity Butler             Marketing Designer
# 53       Vivian Harrell           Financial Controller
# 54           Yuri Berry  Chief Marketing Officer (CMO)
# 55        Zenaida Frank              Software Engineer
# 56       Zorita Serrano              Software Engineer

# %%
employee.dtypes
# Out:
# Name          object
# Position      object
# Office        object
# Age            int64
# Start date    object
# Salary        object
# dtype: object

# %%
import numpy as np
employee = ps.read_table("C:/MyDocuments/ProfessionalDevelopment/TechnicalSkillDevelopment/DataScience/UdemyCourses/LearnDataAnalysisWithPandas/Resources/Tab_separated_values.tsv")
#employee.select_dtypes(include=[np.number]).dtypes

# %%
employee.describe()
# Out:
#              Age
# count  57.000000
# mean   42.736842
# std    14.877507
# min    19.000000
# 25%    30.000000
# 50%    42.000000
# 75%    56.000000
# max    66.000000

# %%
#find out number of columns and rows
employee.shape
# Out:
# (57, 6)

# %%
employee["Name Salary"] = employee["Name"]+employee["Salary"]
employee.head()
# Out:
#              Name                       Position         Office  Age  \
# 0      Airi Satou                     Accountant          Tokyo   33
# 1  Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2      Ashton Cox        Junior Technical Author  San Francisco   66
# 3   Bradley Greer              Software Engineer         London   41
# 4  Brenden Wagner              Software Engineer  San Francisco   28
#
#    Start date      Salary               Name Salary
# 0  2008/11/28    $162,700        Airi Satou$162,700
# 1  2009/10/09  $1,200,000  Angelica Ramos$1,200,000
# 2  2009/01/12     $86,000         Ashton Cox$86,000
# 3  2012/10/13    $132,000     Bradley Greer$132,000
# 4  2011/06/07    $206,850    Brenden Wagner$206,850

# %%
employee.drop(['Age'], axis=1, inplace=True)
employee.head()
# Out:
#              Name                       Position         Office  Start date  \
# 0      Airi Satou                     Accountant          Tokyo  2008/11/28
# 1  Angelica Ramos  Chief Executive Officer (CEO)         London  2009/10/09
# 2      Ashton Cox        Junior Technical Author  San Francisco  2009/01/12
# 3   Bradley Greer              Software Engineer         London  2012/10/13
# 4  Brenden Wagner              Software Engineer  San Francisco  2011/06/07
#
#        Salary               Name Salary
# 0    $162,700        Airi Satou$162,700
# 1  $1,200,000  Angelica Ramos$1,200,000
# 2     $86,000         Ashton Cox$86,000
# 3    $132,000     Bradley Greer$132,000
# 4    $206,850    Brenden Wagner$206,850

# %%
employee = ps.read_table("C:/MyDocuments/ProfessionalDevelopment/TechnicalSkillDevelopment/DataScience/UdemyCourses/LearnDataAnalysisWithPandas/Resources/Tab_separated_values.tsv")
employee.head()
cols = ["Name", "Pos", "Ofc", "Age", "S_date", "Sal"]
employee.columns = cols
employee.head()
# Out:
#              Name                            Pos            Ofc  Age  \
# 0      Airi Satou                     Accountant          Tokyo   33
# 1  Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2      Ashton Cox        Junior Technical Author  San Francisco   66
# 3   Bradley Greer              Software Engineer         London   41
# 4  Brenden Wagner              Software Engineer  San Francisco   28
#
#        S_date         Sal
# 0  2008/11/28    $162,700
# 1  2009/10/09  $1,200,000
# 2  2009/01/12     $86,000
# 3  2012/10/13    $132,000
# 4  2011/06/07    $206,850

# %%
employee.sort_values(by="Age", ascending=True)
# Out:
#                    Name                            Pos            Ofc  Age  \
# 48  Tatyana Fitzpatrick              Regional Director         London   19
# 45            Shou Itou             Regional Marketing          Tokyo   20
# 7          Caesar Vance              Pre-Sales Support       New York   21
# 32           Lael Greer          Systems Administrator         London   21
# 18         Gavin Cortez                    Team Leader  San Francisco   22
# 40          Quinn Flynn                   Support Lead      Edinburgh   22
# 9          Cedric Kelly    Senior Javascript Developer      Edinburgh   22
# 46          Sonya Frost              Software Engineer      Edinburgh   23
# 14         Doris Wilder                Sales Assistant         Sidney   23
# 39    Prescott Bartlett               Technical Author         London   27
# 13         Donna Snider               Customer Support       New York   27
# 4        Brenden Wagner              Software Engineer  San Francisco   28
# 30       Jennifer Chang              Regional Director      Singapore   28
# 34        Michael Bruce           Javascript Developer      Singapore   29
# 27          Jena Gaines                 Office Manager         London   30
# 31      Jonas Alexander                      Developer  San Francisco   30
# 28     Jenette Caldwell               Development Lead       New York   30
# 0            Airi Satou                     Accountant          Tokyo   33
# 12             Dai Rios                 Personnel Lead      Edinburgh   35
# 10      Charde Marshall              Regional Director  San Francisco   36
# 36       Michelle House         Integration Specialist         Sidney   37
# 51       Timothy Mooney                 Office Manager         London   37
# 42      Sakura Yamamoto               Support Engineer          Tokyo   37
# 6            Bruno Nash              Software Engineer         London   38
# 11        Colleen Hurst           Javascript Developer  San Francisco   39
# 54           Yuri Berry  Chief Marketing Officer (CMO)       New York   40
# 24         Hope Fuentes                      Secretary  San Francisco   41
# 3         Bradley Greer              Software Engineer         London   41
# 19          Gavin Joyce                      Developer      Edinburgh   42
# 29      Jennifer Acosta    Junior Javascript Developer      Edinburgh   43
# 21        Haley Kennedy      Senior Marketing Designer         London   43
# 33       Martena Mccray             Post-Sales support      Edinburgh   46
# 8          Cara Stevens                Sales Assistant       New York   46
# 52         Unity Butler             Marketing Designer  San Francisco   47
# 22      Hermione Butler              Regional Director         London   47
# 1        Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 15         Finn Camacho               Support Engineer  San Francisco   47
# 16          Fiona Green  Chief Operating Officer (COO)  San Francisco   48
# 44          Shad Decker              Regional Director      Edinburgh   51
# 25      Howard Hatfield                 Office Manager  San Francisco   51
# 47           Suki Burks                      Developer         London   53
# 41       Rhona Davidson         Integration Specialist          Tokyo   55
# 56       Zorita Serrano              Software Engineer  San Francisco   56
# 23      Herrod Chandler                Sales Assistant  San Francisco   59
# 20        Gloria Little          Systems Administrator       New York   59
# 49          Thor Walton                      Developer       New York   61
# 50          Tiger Nixon               System Architect      Edinburgh   61
# 5    Brielle Williamson         Integration Specialist       New York   61
# 53       Vivian Harrell           Financial Controller  San Francisco   62
# 17      Garrett Winters                     Accountant          Tokyo   63
# 55        Zenaida Frank              Software Engineer       New York   63
# 43        Serge Baldwin               Data Coordinator      Singapore   64
# 38            Paul Byrd  Chief Financial Officer (CFO)       New York   64
# 37         Olivia Liang               Support Engineer      Singapore   64
# 26     Jackson Bradshaw                       Director       New York   65
# 2            Ashton Cox        Junior Technical Author  San Francisco   66
# 35        Michael Silva             Marketing Designer         London   66
#
#         S_date         Sal
# 48  2010/03/17    $385,750
# 45  2011/08/14    $163,000
# 7   2011/12/12    $106,450
# 32  2009/02/27    $103,500
# 18  2008/10/26    $235,500
# 40  2013/03/03    $342,000
# 9   2012/03/29    $433,060
# 46  2008/12/13    $103,600
# 14  2010/09/20     $85,600
# 39  2011/05/07    $145,000
# 13  2011/01/25    $112,000
# 4   2011/06/07    $206,850
# 30  2010/11/14    $357,650
# 34  2011/06/27    $183,000
# 27  2008/12/19     $90,560
# 31  2010/07/14     $86,500
# 28  2011/09/03    $345,000
# 0   2008/11/28    $162,700
# 12  2012/09/26    $217,500
# 10  2008/10/16    $470,600
# 36  2011/06/02     $95,400
# 51  2008/12/11    $136,200
# 42  2009/08/19    $139,575
# 6   2011/05/03    $163,500
# 11  2009/09/15    $205,500
# 54  2009/06/25    $675,000
# 24  2010/02/12    $109,850
# 3   2012/10/13    $132,000
# 19  2010/12/22     $92,575
# 29  2013/02/01     $75,650
# 21  2012/12/18    $313,500
# 33  2011/03/09    $324,050
# 8   2011/12/06    $145,600
# 52  2009/12/09     $85,675
# 22  2011/03/21    $356,250
# 1   2009/10/09  $1,200,000
# 15  2009/07/07     $87,500
# 16  2010/03/11    $850,000
# 44  2008/11/13    $183,000
# 25  2008/12/16    $164,500
# 47  2009/10/22    $114,500
# 41  2010/10/14    $327,900
# 56  2012/06/01    $115,000
# 23  2012/08/06    $137,500
# 20  2009/04/10    $237,500
# 49  2013/08/11     $98,540
# 50  2011/04/25    $320,800
# 5   2012/12/02    $372,000
# 53  2009/02/14    $452,500
# 17  2011/07/25    $170,750
# 55  2010/01/04    $125,250
# 43  2012/04/09    $138,575
# 38  2010/06/09    $725,000
# 37  2011/02/03    $234,500
# 26  2008/09/26    $645,750
# 2   2009/01/12     $86,000
# 35  2012/11/27    $198,500

# %%
employee["Name"].sort_values().head()
# Out:
# 0        Airi Satou
# 1    Angelica Ramos
# 2        Ashton Cox
# 3     Bradley Greer
# 4    Brenden Wagner
# Name: Name, dtype: object

# %%
b
# Out:
#                    Name                          Pos            Ofc  Age  \
# 48  Tatyana Fitzpatrick            Regional Director         London   19
# 45            Shou Itou           Regional Marketing          Tokyo   20
# 7          Caesar Vance            Pre-Sales Support       New York   21
# 32           Lael Greer        Systems Administrator         London   21
# 9          Cedric Kelly  Senior Javascript Developer      Edinburgh   22
# 18         Gavin Cortez                  Team Leader  San Francisco   22
# 40          Quinn Flynn                 Support Lead      Edinburgh   22
# 14         Doris Wilder              Sales Assistant         Sidney   23
# 46          Sonya Frost            Software Engineer      Edinburgh   23
# 13         Donna Snider             Customer Support       New York   27
# 39    Prescott Bartlett             Technical Author         London   27
# 4        Brenden Wagner            Software Engineer  San Francisco   28
# 30       Jennifer Chang            Regional Director      Singapore   28
# 34        Michael Bruce         Javascript Developer      Singapore   29
#
#         S_date       Sal
# 48  2010/03/17  $385,750
# 45  2011/08/14  $163,000
# 7   2011/12/12  $106,450
# 32  2009/02/27  $103,500
# 9   2012/03/29  $433,060
# 18  2008/10/26  $235,500
# 40  2013/03/03  $342,000
# 14  2010/09/20   $85,600
# 46  2008/12/13  $103,600
# 13  2011/01/25  $112,000
# 39  2011/05/07  $145,000
# 4   2011/06/07  $206,850
# 30  2010/11/14  $357,650
# 34  2011/06/27  $183,000

# %%
employee[(employee.Age < 30 ) & (employee.Ofc == "London")]
# Out:
#                    Name                    Pos     Ofc  Age      S_date  \
# 32           Lael Greer  Systems Administrator  London   21  2009/02/27
# 39    Prescott Bartlett       Technical Author  London   27  2011/05/07
# 48  Tatyana Fitzpatrick      Regional Director  London   19  2010/03/17
#
#          Sal
# 32  $103,500
# 39  $145,000
# 48  $385,750

# %%
#filter columns
cols = ["Name", "Pos"]
employee[(employee.Age<40) & (employee.Ofc=="London")][cols]
# Out:
#                    Name                    Pos
# 6            Bruno Nash      Software Engineer
# 27          Jena Gaines         Office Manager
# 32           Lael Greer  Systems Administrator
# 39    Prescott Bartlett       Technical Author
# 48  Tatyana Fitzpatrick      Regional Director
# 51       Timothy Mooney         Office Manager

# %%
#chapter 6 - •	Filtering 
employee[(employee.Name!="Airi Satou") & (employee.Name!="Angelica Ramos") & (employee.Name!="Bradley Greer")]
# Out:
#                    Name                            Pos            Ofc  Age  \
# 2            Ashton Cox        Junior Technical Author  San Francisco   66
# 4        Brenden Wagner              Software Engineer  San Francisco   28
# 5    Brielle Williamson         Integration Specialist       New York   61
# 6            Bruno Nash              Software Engineer         London   38
# 7          Caesar Vance              Pre-Sales Support       New York   21
# 8          Cara Stevens                Sales Assistant       New York   46
# 9          Cedric Kelly    Senior Javascript Developer      Edinburgh   22
# 10      Charde Marshall              Regional Director  San Francisco   36
# 11        Colleen Hurst           Javascript Developer  San Francisco   39
# 12             Dai Rios                 Personnel Lead      Edinburgh   35
# 13         Donna Snider               Customer Support       New York   27
# 14         Doris Wilder                Sales Assistant         Sidney   23
# 15         Finn Camacho               Support Engineer  San Francisco   47
# 16          Fiona Green  Chief Operating Officer (COO)  San Francisco   48
# 17      Garrett Winters                     Accountant          Tokyo   63
# 18         Gavin Cortez                    Team Leader  San Francisco   22
# 19          Gavin Joyce                      Developer      Edinburgh   42
# 20        Gloria Little          Systems Administrator       New York   59
# 21        Haley Kennedy      Senior Marketing Designer         London   43
# 22      Hermione Butler              Regional Director         London   47
# 23      Herrod Chandler                Sales Assistant  San Francisco   59
# 24         Hope Fuentes                      Secretary  San Francisco   41
# 25      Howard Hatfield                 Office Manager  San Francisco   51
# 26     Jackson Bradshaw                       Director       New York   65
# 27          Jena Gaines                 Office Manager         London   30
# 28     Jenette Caldwell               Development Lead       New York   30
# 29      Jennifer Acosta    Junior Javascript Developer      Edinburgh   43
# 30       Jennifer Chang              Regional Director      Singapore   28
# 31      Jonas Alexander                      Developer  San Francisco   30
# 32           Lael Greer          Systems Administrator         London   21
# 33       Martena Mccray             Post-Sales support      Edinburgh   46
# 34        Michael Bruce           Javascript Developer      Singapore   29
# 35        Michael Silva             Marketing Designer         London   66
# 36       Michelle House         Integration Specialist         Sidney   37
# 37         Olivia Liang               Support Engineer      Singapore   64
# 38            Paul Byrd  Chief Financial Officer (CFO)       New York   64
# 39    Prescott Bartlett               Technical Author         London   27
# 40          Quinn Flynn                   Support Lead      Edinburgh   22
# 41       Rhona Davidson         Integration Specialist          Tokyo   55
# 42      Sakura Yamamoto               Support Engineer          Tokyo   37
# 43        Serge Baldwin               Data Coordinator      Singapore   64
# 44          Shad Decker              Regional Director      Edinburgh   51
# 45            Shou Itou             Regional Marketing          Tokyo   20
# 46          Sonya Frost              Software Engineer      Edinburgh   23
# 47           Suki Burks                      Developer         London   53
# 48  Tatyana Fitzpatrick              Regional Director         London   19
# 49          Thor Walton                      Developer       New York   61
# 50          Tiger Nixon               System Architect      Edinburgh   61
# 51       Timothy Mooney                 Office Manager         London   37
# 52         Unity Butler             Marketing Designer  San Francisco   47
# 53       Vivian Harrell           Financial Controller  San Francisco   62
# 54           Yuri Berry  Chief Marketing Officer (CMO)       New York   40
# 55        Zenaida Frank              Software Engineer       New York   63
# 56       Zorita Serrano              Software Engineer  San Francisco   56
#
#         S_date       Sal
# 2   2009/01/12   $86,000
# 4   2011/06/07  $206,850
# 5   2012/12/02  $372,000
# 6   2011/05/03  $163,500
# 7   2011/12/12  $106,450
# 8   2011/12/06  $145,600
# 9   2012/03/29  $433,060
# 10  2008/10/16  $470,600
# 11  2009/09/15  $205,500
# 12  2012/09/26  $217,500
# 13  2011/01/25  $112,000
# 14  2010/09/20   $85,600
# 15  2009/07/07   $87,500
# 16  2010/03/11  $850,000
# 17  2011/07/25  $170,750
# 18  2008/10/26  $235,500
# 19  2010/12/22   $92,575
# 20  2009/04/10  $237,500
# 21  2012/12/18  $313,500
# 22  2011/03/21  $356,250
# 23  2012/08/06  $137,500
# 24  2010/02/12  $109,850
# 25  2008/12/16  $164,500
# 26  2008/09/26  $645,750
# 27  2008/12/19   $90,560
# 28  2011/09/03  $345,000
# 29  2013/02/01   $75,650
# 30  2010/11/14  $357,650
# 31  2010/07/14   $86,500
# 32  2009/02/27  $103,500
# 33  2011/03/09  $324,050
# 34  2011/06/27  $183,000
# 35  2012/11/27  $198,500
# 36  2011/06/02   $95,400
# 37  2011/02/03  $234,500
# 38  2010/06/09  $725,000
# 39  2011/05/07  $145,000
# 40  2013/03/03  $342,000
# 41  2010/10/14  $327,900
# 42  2009/08/19  $139,575
# 43  2012/04/09  $138,575
# 44  2008/11/13  $183,000
# 45  2011/08/14  $163,000
# 46  2008/12/13  $103,600
# 47  2009/10/22  $114,500
# 48  2010/03/17  $385,750
# 49  2013/08/11   $98,540
# 50  2011/04/25  $320,800
# 51  2008/12/11  $136,200
# 52  2009/12/09   $85,675
# 53  2009/02/14  $452,500
# 54  2009/06/25  $675,000
# 55  2010/01/04  $125,250
# 56  2012/06/01  $115,000

# %%
#chapter 6 - mean()
employee.mean()
# Out:
# Age    42.736842
# dtype: float64

# %%
#Chapter 6 - •	String manipulation techniques (upper, lower, replace)
employee.Name.str.upper().head()
# Out:
# 0        AIRI SATOU
# 1    ANGELICA RAMOS
# 2        ASHTON COX
# 3     BRADLEY GREER
# 4    BRENDEN WAGNER
# Name: Name, dtype: object

# %%
employee.Pos.str.contains("Software").head()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# Name: Pos, dtype: bool

# %%
employee[employee.Pos.str.contains("Software")].head()
# Out:
#               Name                Pos            Ofc  Age      S_date  \
# 3    Bradley Greer  Software Engineer         London   41  2012/10/13
# 4   Brenden Wagner  Software Engineer  San Francisco   28  2011/06/07
# 6       Bruno Nash  Software Engineer         London   38  2011/05/03
# 46     Sonya Frost  Software Engineer      Edinburgh   23  2008/12/13
# 55   Zenaida Frank  Software Engineer       New York   63  2010/01/04
#
#          Sal
# 3   $132,000
# 4   $206,850
# 6   $163,500
# 46  $103,600
# 55  $125,250

# %%
#Chapter 6- o	String replace
employee.Pos.str.replace("Engineer", "Developer").head()
# Out:
# 0                       Accountant
# 1    Chief Executive Officer (CEO)
# 2          Junior Technical Author
# 3               Software Developer
# 4               Software Developer
# Name: Pos, dtype: object

# %%
#chapter 6 - Aggregations
employee.Age.min()
employee.Age.max()
# Out:
# 19

# %%
#chapter 6 - •	Groupby clauses (like you use in SQL Aggregations)
employee.groupby("Pos").Age.min().head()
# Out:
# Pos
# Accountant                       33
# Chief Executive Officer (CEO)    47
# Chief Financial Officer (CFO)    64
# Chief Marketing Officer (CMO)    40
# Chief Operating Officer (COO)    48
# Name: Age, dtype: int64

# %%
#chapter 6 - •	Groupby clauses (like you use in SQL Aggregations)
employee.groupby("Pos").Age.agg(['count', 'min', 'max']).head()
# Out:
#                                count  min  max
# Pos
# Accountant                         2   33   63
# Chief Executive Officer (CEO)      1   47   47
# Chief Financial Officer (CFO)      1   64   64
# Chief Marketing Officer (CMO)      1   40   40
# Chief Operating Officer (COO)      1   48   48

# %%
#chapter homework - calculate the mean rowwise and columnwise
import numpy as np
iris = ps.read_table("C:/MyDocuments/ProfessionalDevelopment/TechnicalSkillDevelopment/DataScience/UdemyCourses/LearnDataAnalysisWithPandas/Resources/Iris.csv", sep=",")

# %%
iris.head()
# Out:
#   sepal length,sepal width,petal length,petal width,iris,,,,
# 0                    5.1,3.5,1.4,0.2,Iris-setosa,,,,
# 1                      4.9,3,1.4,0.2,Iris-setosa,,,,
# 2                    4.7,3.2,1.3,0.2,Iris-setosa,,,,
# 3                    4.6,3.1,1.5,0.2,Iris-setosa,,,,
# 4                      5,3.6,1.4,0.2,Iris-setosa,,,,

# %%
iris.mean()
# Out:
# sepal length                            (5.8433333333333355+0j)
# sepal width                              (3.054000000000001+0j)
# petal length                            (3.7586666666666697+0j)
# petal width                             (1.1986666666666674+0j)
# iris            (8.30747206291045e-309+9.197469912385895e-309j)
# Unnamed: 5                                                  NaN
# Unnamed: 6                                                  NaN
# Unnamed: 7                                                  NaN
# Unnamed: 8                                                  NaN
# dtype: complex128

# %%
#add a new column to store mean that's calculated by rows
iris["mean"]=iris.mean(axis=1)
iris.head()
# Out:
#    sepal length  sepal width  petal length  petal width         iris  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8   mean
# 0         NaN         NaN         NaN         NaN  2.550
# 1         NaN         NaN         NaN         NaN  2.375
# 2         NaN         NaN         NaN         NaN  2.350
# 3         NaN         NaN         NaN         NaN  2.350
# 4         NaN         NaN         NaN         NaN  2.550

# %%
#calculate mean by columns
iris.mean(axis=0)
# Out:
# sepal length                             (5.8433333333333355+0j)
# sepal width                               (3.054000000000001+0j)
# petal length                             (3.7586666666666697+0j)
# petal width                              (1.1986666666666674+0j)
# iris            (2.976469694290114e-88+2.2373972069411116e-145j)
# Unnamed: 5                                                   NaN
# Unnamed: 6                                                   NaN
# Unnamed: 7                                                   NaN
# Unnamed: 8                                                   NaN
# mean                                      (3.463666666666666+0j)
# dtype: complex128

# %%
#chapter 7 - loc : select rows and columns, like table slicing
iris.loc[0, :]
# Out:
# sepal length            5.1
# sepal width             3.5
# petal length            1.4
# petal width             0.2
# iris            Iris-setosa
# Unnamed: 5              NaN
# Unnamed: 6              NaN
# Unnamed: 7              NaN
# Unnamed: 8              NaN
# mean                   2.55
# Name: 0, dtype: object

# %%
iris.loc[0:3, :]
# Out:
#    sepal length  sepal width  petal length  petal width         iris  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8   mean
# 0         NaN         NaN         NaN         NaN  2.550
# 1         NaN         NaN         NaN         NaN  2.375
# 2         NaN         NaN         NaN         NaN  2.350
# 3         NaN         NaN         NaN         NaN  2.350

# %%
iris.loc[0:3, ["sepal length", "petal width", "iris"]]
# Out:
#    sepal length  petal width         iris
# 0           5.1          0.2  Iris-setosa
# 1           4.9          0.2  Iris-setosa
# 2           4.7          0.2  Iris-setosa
# 3           4.6          0.2  Iris-setosa

# %%
iris.loc[iris.iris=="Iris-setosa"]
# Out:
#     sepal length  sepal width  petal length  petal width         iris  \
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# 12           4.8          3.0           1.4          0.1  Iris-setosa
# 13           4.3          3.0           1.1          0.1  Iris-setosa
# 14           5.8          4.0           1.2          0.2  Iris-setosa
# 15           5.7          4.4           1.5          0.4  Iris-setosa
# 16           5.4          3.9           1.3          0.4  Iris-setosa
# 17           5.1          3.5           1.4          0.3  Iris-setosa
# 18           5.7          3.8           1.7          0.3  Iris-setosa
# 19           5.1          3.8           1.5          0.3  Iris-setosa
# 20           5.4          3.4           1.7          0.2  Iris-setosa
# 21           5.1          3.7           1.5          0.4  Iris-setosa
# 22           4.6          3.6           1.0          0.2  Iris-setosa
# 23           5.1          3.3           1.7          0.5  Iris-setosa
# 24           4.8          3.4           1.9          0.2  Iris-setosa
# 25           5.0          3.0           1.6          0.2  Iris-setosa
# 26           5.0          3.4           1.6          0.4  Iris-setosa
# 27           5.2          3.5           1.5          0.2  Iris-setosa
# 28           5.2          3.4           1.4          0.2  Iris-setosa
# 29           4.7          3.2           1.6          0.2  Iris-setosa
# 30           4.8          3.1           1.6          0.2  Iris-setosa
# 31           5.4          3.4           1.5          0.4  Iris-setosa
# 32           5.2          4.1           1.5          0.1  Iris-setosa
# 33           5.5          4.2           1.4          0.2  Iris-setosa
# 34           4.9          3.1           1.5          0.1  Iris-setosa
# 35           5.0          3.2           1.2          0.2  Iris-setosa
# 36           5.5          3.5           1.3          0.2  Iris-setosa
# 37           4.9          3.1           1.5          0.1  Iris-setosa
# 38           4.4          3.0           1.3          0.2  Iris-setosa
# 39           5.1          3.4           1.5          0.2  Iris-setosa
# 40           5.0          3.5           1.3          0.3  Iris-setosa
# 41           4.5          2.3           1.3          0.3  Iris-setosa
# 42           4.4          3.2           1.3          0.2  Iris-setosa
# 43           5.0          3.5           1.6          0.6  Iris-setosa
# 44           5.1          3.8           1.9          0.4  Iris-setosa
# 45           4.8          3.0           1.4          0.3  Iris-setosa
# 46           5.1          3.8           1.6          0.2  Iris-setosa
# 47           4.6          3.2           1.4          0.2  Iris-setosa
# 48           5.3          3.7           1.5          0.2  Iris-setosa
# 49           5.0          3.3           1.4          0.2  Iris-setosa
#
#     Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8   mean
# 0          NaN         NaN         NaN         NaN  2.550
# 1          NaN         NaN         NaN         NaN  2.375
# 2          NaN         NaN         NaN         NaN  2.350
# 3          NaN         NaN         NaN         NaN  2.350
# 4          NaN         NaN         NaN         NaN  2.550
# 5          NaN         NaN         NaN         NaN  2.850
# 6          NaN         NaN         NaN         NaN  2.425
# 7          NaN         NaN         NaN         NaN  2.525
# 8          NaN         NaN         NaN         NaN  2.225
# 9          NaN         NaN         NaN         NaN  2.400
# 10         NaN         NaN         NaN         NaN  2.700
# 11         NaN         NaN         NaN         NaN  2.500
# 12         NaN         NaN         NaN         NaN  2.325
# 13         NaN         NaN         NaN         NaN  2.125
# 14         NaN         NaN         NaN         NaN  2.800
# 15         NaN         NaN         NaN         NaN  3.000
# 16         NaN         NaN         NaN         NaN  2.750
# 17         NaN         NaN         NaN         NaN  2.575
# 18         NaN         NaN         NaN         NaN  2.875
# 19         NaN         NaN         NaN         NaN  2.675
# 20         NaN         NaN         NaN         NaN  2.675
# 21         NaN         NaN         NaN         NaN  2.675
# 22         NaN         NaN         NaN         NaN  2.350
# 23         NaN         NaN         NaN         NaN  2.650
# 24         NaN         NaN         NaN         NaN  2.575
# 25         NaN         NaN         NaN         NaN  2.450
# 26         NaN         NaN         NaN         NaN  2.600
# 27         NaN         NaN         NaN         NaN  2.600
# 28         NaN         NaN         NaN         NaN  2.550
# 29         NaN         NaN         NaN         NaN  2.425
# 30         NaN         NaN         NaN         NaN  2.425
# 31         NaN         NaN         NaN         NaN  2.675
# 32         NaN         NaN         NaN         NaN  2.725
# 33         NaN         NaN         NaN         NaN  2.825
# 34         NaN         NaN         NaN         NaN  2.400
# 35         NaN         NaN         NaN         NaN  2.400
# 36         NaN         NaN         NaN         NaN  2.625
# 37         NaN         NaN         NaN         NaN  2.400
# 38         NaN         NaN         NaN         NaN  2.225
# 39         NaN         NaN         NaN         NaN  2.550
# 40         NaN         NaN         NaN         NaN  2.525
# 41         NaN         NaN         NaN         NaN  2.100
# 42         NaN         NaN         NaN         NaN  2.275
# 43         NaN         NaN         NaN         NaN  2.675
# 44         NaN         NaN         NaN         NaN  2.800
# 45         NaN         NaN         NaN         NaN  2.375
# 46         NaN         NaN         NaN         NaN  2.675
# 47         NaN         NaN         NaN         NaN  2.350
# 48         NaN         NaN         NaN         NaN  2.675
# 49         NaN         NaN         NaN         NaN  2.475

# %%
employee = ps.read_table("C:/MyDocuments/ProfessionalDevelopment/TechnicalSkillDevelopment/DataScience/UdemyCourses/LearnDataAnalysisWithPandas/Resources/Tab_separated_values_missingvalues.tsv")
employee.head()
employee.shape
# Out:
# (57, 6)

# %%
#drop rows with any empty value
employee.dropna(how="any").shape
# Out:
# (54, 6)

# %%
employee.fillna(value=0).head()
# Out:
#              Name                       Position         Office  Age  \
# 0      Airi Satou                     Accountant          Tokyo   33
# 1  Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2      Ashton Cox        Junior Technical Author  San Francisco   66
# 3   Bradley Greer              Software Engineer         London   41
# 4  Brenden Wagner              Software Engineer  San Francisco   28
#
#    Start date    Salary
# 0  2008/11/28         0
# 1  2009/10/09         0
# 2  2009/01/12   $86,000
# 3  2012/10/13  $132,000
# 4  2011/06/07         0

# %%
#chapter 8 - work with plot
iris = ps.read_csv("C:/MyDocuments/ProfessionalDevelopment/TechnicalSkillDevelopment/DataScience/UdemyCourses/LearnDataAnalysisWithPandas/Resources/Iris.csv", sep=",")
iris.head()
iris.shape
# Out:
# (150, 9)

# %%
iris.head()
# Out:
#    sepal length  sepal width  petal length  petal width         iris  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN

# %%
cols=["sepal length", "iris"]
iris[cols].plot()

# %%
#join tables
dataframe1 = ps.DataFrame({"employee":["ABC", "XYZ", "MNO"], "age":[22, 35, 43]})
dataframe1
# Out:
#   employee  age
# 0      ABC   22
# 1      XYZ   35
# 2      MNO   43

# %%
dataframe2 = ps.DataFrame({"employee":["ABC", "XYZ", "EFG"], "salary":[10000, 30000, 25000]})
dataframe2
# Out:
#   employee  salary
# 0      ABC   10000
# 1      XYZ   30000
# 2      EFG   25000

# %%
#inner join
dataframe3 = ps.merge(dataframe1, dataframe2, on="employee")
dataframe3
# Out:
#   employee  age  salary
# 0      ABC   22   10000
# 1      XYZ   35   30000

# %%
#outer join
dataframe4 = ps.merge(dataframe1, dataframe2, how="outer")
dataframe4
# Out:
#   employee   age   salary
# 0      ABC  22.0  10000.0
# 1      XYZ  35.0  30000.0
# 2      MNO  43.0      NaN
# 3      EFG   NaN  25000.0

# %%
dataframe3 = ps.merge(dataframe1, dataframe2, how="left")
dataframe3
# Out:
#   employee  age   salary
# 0      ABC   22  10000.0
# 1      XYZ   35  30000.0
# 2      MNO   43      NaN

# %%
dataframe3 = ps.merge(dataframe1, dataframe2, how="right")
dataframe3
# Out:
#   employee   age  salary
# 0      ABC  22.0   10000
# 1      XYZ  35.0   30000
# 2      EFG   NaN   25000

# %%
#chapter 9 - pivot data
webhits = ps.read_csv("C:/MyDocuments/ProfessionalDevelopment/TechnicalSkillDevelopment/DataScience/UdemyCourses/LearnDataAnalysisWithPandas/Resources/webhits.csv")
webhits
# Out:
#         Date Page_Name  Hits
# 0   1/1/2019       ABC    33
# 1   1/2/2019       EFG    22
# 2   1/3/2019       XYZ    44
# 3   1/1/2019       MNO    55
# 4   1/2/2019       ABC    21
# 5   1/3/2019       EFG    30
# 6   1/1/2019       XYZ    40
# 7   1/2/2019       MNO    51
# 8   1/3/2019       ABC    34
# 9   1/1/2019       EFG    67
# 10  1/2/2019       XYZ    25
# 11  1/3/2019       MNO    43

# %%
#pivode data
webhits.pivot(index="Page_Name", columns="Date")
# Out:
#               Hits
# Date      1/1/2019 1/2/2019 1/3/2019
# Page_Name
# ABC             33       21       34
# EFG             67       22       30
# MNO             55       51       43
# XYZ             40       25       44

# %%
##pivot table
webhits.pivot_table(index="Page_Name", aggfunc="sum")
# Out:
#            Hits
# Page_Name
# ABC          88
# EFG         119
# MNO         149
# XYZ         109

# %%
webhits.pivot_table(index="Page_Name", aggfunc="mean")
# Out:
#                 Hits
# Page_Name
# ABC        29.333333
# EFG        39.666667
# MNO        49.666667
# XYZ        36.333333

# %%
webhits.pivot_table(index="Page_Name", aggfunc="count")
# Out:
#            Date  Hits
# Page_Name
# ABC           3     3
# EFG           3     3
# MNO           3     3
# XYZ           3     3

# %%
webhits
# Out:
#         Date Page_Name  Hits
# 0   1/1/2019       ABC    33
# 1   1/2/2019       EFG    22
# 2   1/3/2019       XYZ    44
# 3   1/1/2019       MNO    55
# 4   1/2/2019       ABC    21
# 5   1/3/2019       EFG    30
# 6   1/1/2019       XYZ    40
# 7   1/2/2019       MNO    51
# 8   1/3/2019       ABC    34
# 9   1/1/2019       EFG    67
# 10  1/2/2019       XYZ    25
# 11  1/3/2019       MNO    43

# %%
webhits.shift(1)
# Out:
#         Date Page_Name  Hits
# 0        NaN       NaN   NaN
# 1   1/1/2019       ABC  33.0
# 2   1/2/2019       EFG  22.0
# 3   1/3/2019       XYZ  44.0
# 4   1/1/2019       MNO  55.0
# 5   1/2/2019       ABC  21.0
# 6   1/3/2019       EFG  30.0
# 7   1/1/2019       XYZ  40.0
# 8   1/2/2019       MNO  51.0
# 9   1/3/2019       ABC  34.0
# 10  1/1/2019       EFG  67.0
# 11  1/2/2019       XYZ  25.0

# %%
webhits.shift(-1)
# Out:
#         Date Page_Name  Hits
# 0   1/2/2019       EFG  22.0
# 1   1/3/2019       XYZ  44.0
# 2   1/1/2019       MNO  55.0
# 3   1/2/2019       ABC  21.0
# 4   1/3/2019       EFG  30.0
# 5   1/1/2019       XYZ  40.0
# 6   1/2/2019       MNO  51.0
# 7   1/3/2019       ABC  34.0
# 8   1/1/2019       EFG  67.0
# 9   1/2/2019       XYZ  25.0
# 10  1/3/2019       MNO  43.0
# 11       NaN       NaN   NaN

# %%
webhits.shift(-1).to_csv("C:/MyDocuments/ProfessionalDevelopment/TechnicalSkillDevelopment/DataScience/UdemyCourses/LearnDataAnalysisWithPandas/Resources/webhits_shiftup.csv")

# %%
webhits.shift(2).to_csv("C:/MyDocuments/ProfessionalDevelopment/TechnicalSkillDevelopment/DataScience/UdemyCourses/LearnDataAnalysisWithPandas/Resources/webhits_shift_somecolumns.csv", columns=["Date", "Page_Name"])

# %%
#use shift to calculate delta
webhits["Prev_hits"]=webhits["Hits"].shift(1)
webhits
# Out:
#         Date Page_Name  Hits  prev_hits  Prev_hits
# 0   1/1/2019       ABC    33        NaN        NaN
# 1   1/2/2019       EFG    22       33.0       33.0
# 2   1/3/2019       XYZ    44       22.0       22.0
# 3   1/1/2019       MNO    55       44.0       44.0
# 4   1/2/2019       ABC    21       55.0       55.0
# 5   1/3/2019       EFG    30       21.0       21.0
# 6   1/1/2019       XYZ    40       30.0       30.0
# 7   1/2/2019       MNO    51       40.0       40.0
# 8   1/3/2019       ABC    34       51.0       51.0
# 9   1/1/2019       EFG    67       34.0       34.0
# 10  1/2/2019       XYZ    25       67.0       67.0
# 11  1/3/2019       MNO    43       25.0       25.0

# %%
webhits["Hits_delta"] = webhits["Hits"]-webhits["Prev_hits"]
webhits
# Out:
#         Date Page_Name  Hits  prev_hits  Prev_hits  Hits_delta
# 0   1/1/2019       ABC    33        NaN        NaN         NaN
# 1   1/2/2019       EFG    22       33.0       33.0       -11.0
# 2   1/3/2019       XYZ    44       22.0       22.0        22.0
# 3   1/1/2019       MNO    55       44.0       44.0        11.0
# 4   1/2/2019       ABC    21       55.0       55.0       -34.0
# 5   1/3/2019       EFG    30       21.0       21.0         9.0
# 6   1/1/2019       XYZ    40       30.0       30.0        10.0
# 7   1/2/2019       MNO    51       40.0       40.0        11.0
# 8   1/3/2019       ABC    34       51.0       51.0       -17.0
# 9   1/1/2019       EFG    67       34.0       34.0        33.0
# 10  1/2/2019       XYZ    25       67.0       67.0       -42.0
# 11  1/3/2019       MNO    43       25.0       25.0        18.0
